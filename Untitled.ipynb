# %%
from urllib.request import Request, urlopen
from pyquery import PyQuery

# %%
req = Request ('https://www.dane.gov.co/index.php/indicadores-economicos', None,{'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'})
print(urlopen(req).read())
# Out:
# b'\n<!DOCTYPE html>\n<html lang="es-es" dir="ltr"\n\t  class=\'com_content view-article itemid-3474 j39 mm-hover\'>\n\n<head>\n<meta http-equiv="cache-control" content="max-age=0" />\r\n<meta http-equiv="cache-control" content="no-cache" />\r\n<meta http-equiv="expires" content="0" />\r\n<meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />\r\n<meta http-equiv="pragma" content="no-cache" />\n\t<base href="https://www.dane.gov.co/index.php/indicadores-economicos" />\n\t<meta http-equiv="content-type" content="text/html; charset=utf-8" />\n\t<meta name="keywords" content="DANE, Estad\xc3\xadstica, IPC, IPP" />\n\t<meta name="author" content="Francisco Javier De Castro Ramos" />\n\t<meta name="description" content="indicadores; economicos, cifras, dolar; UVR; uvr; dtf; DTF;" />\n\t<meta name="generator" content="XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" />\n\t<title>INDICADORES  ECON\xc3\x93MICOS  </title>\n\t<link href="/templates/t3_bs3_blank/favicon.ico" rel="shortcut 
# ...

# %%
req = Request ('https://www.dane.gov.co/index.php/indicadores-economicos', None,{'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'})
content = urlopen(req).read()
pq = PyQuery(content)
print(pq)
# Out:
# <html lang="es-es" dir="ltr" class="com_content view-article itemid-3474 j39 mm-hover">
#
# <head>
# <meta http-equiv="cache-control" content="max-age=0"/>&#13;
# <meta http-equiv="cache-control" content="no-cache"/>&#13;
# <meta http-equiv="expires" content="0"/>&#13;
# <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT"/>&#13;
# <meta http-equiv="pragma" content="no-cache"/>
# 	<base href="https://www.dane.gov.co/index.php/indicadores-economicos"/>
# 	<meta http-equiv="content-type" content="text/html; charset=utf-8"/>
# 	<meta name="keywords" content="DANE, Estadística, IPC, IPP"/>
# 	<meta name="author" content="Francisco Javier De Castro Ramos"/>
# 	<meta name="description" content="indicadores; economicos, cifras, dolar; UVR; uvr; dtf; DTF;"/>
# 	<meta name="generator" content="XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"/>
# 	<title>INDICADORES  ECONÓMICOS  </title>
# ...

# %%
req = Request ('https://www.dane.gov.co/index.php/indicadores-economicos', None,{'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'})
content = urlopen(req).read()
pq = PyQuery(content)
trm= str([i.text() for i in pq('table').eq(1)('h1').items()][0]). replace('$','').replace('.','').replace(',','.')
trm =float (trm)
print(trm)

#trm= pq ('table').eq(1)('h1').item() ___eq() nos indica la linea que queremos llamar
# Out:
# 3620.4

# %%
valor_Peso =trm * 20
print(valor_Peso)
# Out:
# 72408.0

# %%
req = Request ('https://www.dane.gov.co/index.php/indicadores-economicos', None,{'User-agent' : 'Mozilla/5.0 (Windows; U; Windows NT 5.1; de; rv:1.9.1.5) Gecko/20091102 Firefox/3.5.5'})
content = urlopen(req).read()
pq = PyQuery(content)
salariominimo = str([i.text() for i in pq('table').eq(7)('h1').items()][0]). replace('$','').replace('.','').replace(',','.')
print(salariominimo)
# Out:
# 908526

# %%
variable = "3.5"

# %%
type(variable)
# Out:
# str

# %%
if str(type(variable)) == 'float':
    print('bien')
else:
    print('mal')
# Out:
# mal

# %%
print(str(type(variable)))
if str(type(variable)) == 'float':
    print('bien')
else:
    print('mal')
# Out:
# <class 'str'>
# mal

# %%
lista = [{'variable': 'salario', 'resultado': 1300000},5,9,10,25]
#[2,5,9,10,25]
# 0 1 2 3  4

# %%
for i in lista:
    print(i)
# Out:
# {'variable': 'salario', 'resultado': 1300000}
# 5
# 9
# 10
# 25
